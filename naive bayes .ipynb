# %%
from xlrd import open_workbook
import math

wb = open_workbook('data_final.xlsx')
sheet = wb.sheet_by_index(0)


route = []
vaicle = []
service = []
behave = []
available = []
traffic = []
experience = []
gender = []


for j in range(1,sheet.nrows):
    route.append(int(sheet.cell_value(j,0)))

for j in range(1,sheet.nrows):
    vaicle.append( int(sheet.cell_value(j,2)))

for j in range(1,sheet.nrows):
    service.append( int(sheet.cell_value(j,1))) 


for j in range(1,sheet.nrows):
    behave.append( int(sheet.cell_value(j,3))) 
    
for j in range(1,sheet.nrows):
    available.append( int(sheet.cell_value(j,4)))
    
for j in range(1,sheet.nrows):
    traffic.append( int(sheet.cell_value(j,5)))
    
for j in range(1,sheet.nrows):
    experience.append( int(sheet.cell_value(j,6)))
    
for j in range(1,sheet.nrows):
    gender.append( int(sheet.cell_value(j,7)))
    
#for j in range(0,len(gender)):
#    print(gender[j])

# %%
total = sheet.nrows-1
p_uber   = service.count(1)/total
p_pathoe = service.count(2)/total
p_shohoz = service.count(3)/total
c11 = c12 = c13 = 0
p_route = []

 
for i in range(1, max(route)+1):
    for j in range(0, len(service)):
        if(route[j] == i):
            if(service[j] == 1):
                c11 +=1
            elif(service[j] == 2):
                c12 +=1
            else:
                c13 +=1
        
    #print(c11," ",c12," ",c13)
    p_route.append(c11/service.count(1))
    p_route.append(c12/service.count(2))
    p_route.append(c13/service.count(3))
    c11 = c12 = c13 = 0

    
#for k in range(0,len(p_route)):
#    print(p_route[k])
    
#print(route.count(3))  
#print(max(route))

# %%
p_behave = []

for i in range(1, max(behave)+1):
    for j in range(0, len(service)):
        #print(j)
        if(behave[j] == i):
            if(service[j] == 1):
                c11 +=1
            elif(service[j] == 2):
                c12 +=1
            else:
                c13 +=1
        
    #print(c11," ",c12," ",c13)
    p_behave.append(c11/service.count(1))
    p_behave.append(c12/service.count(2))
    p_behave.append(c13/service.count(3))
    c11 = c12 = c13 = 0
    
    
#for k in range(0,len(p_behave)):
#    print(p_behave[k])

# %%
p_available = []

for i in range(1, max(available)+1):
    for j in range(0, len(service)):
        #print(j)
        if(available[j] == i):
            if(service[j] == 1):
                c11 +=1
            elif(service[j] == 2):
                c12 +=1
            else:
                c13 +=1
        
    #print(c11," ",c12," ",c13)
    p_available.append(c11/service.count(1))
    p_available.append(c12/service.count(2))
    p_available.append(c13/service.count(3))
    c11 = c12 = c13 = 0
    
    
#for k in range(0,len(p_available)):
#    print(p_available[k])

# %%
p_experience = []

for i in range(1, max(experience)+1):
    for j in range(0, len(service)):
        #print(j)
        if(experience[j] == i):
            if(service[j] == 1):
                c11 +=1
            elif(service[j] == 2):
                c12 +=1
            else:
                c13 +=1
        
    #print(c11," ",c12," ",c13)
    p_experience.append(c11/service.count(1))
    p_experience.append(c12/service.count(2))
    p_experience.append(c13/service.count(3))
    c11 = c12 = c13 = 0
    
    
#for k in range(0,len(p_experience)):
#    print(p_experience[k])

# %%
p_gender = []

for i in range(1, max(traffic)+1):
    for j in range(0, len(service)):
        #print(j)
        if(gender[j] == i):
            if(service[j] == 1):
                c11 +=1
            elif(service[j] == 2):
                c12 +=1
            else:
                c13 +=1
        
    #print(c11," ",c12," ",c13)
    p_gender.append(c11/service.count(1))
    p_gender.append(c12/service.count(2))
    p_gender.append(c13/service.count(3))
    c11 = c12 = c13 = 0
    
    
#for k in range(0,len(p_gender)):
#    print(p_gender[k])

# %%
p_traffic = []

for i in range(1, max(traffic)+1):
    for j in range(0, len(service)):
        #print(j)
        if(traffic[j] == i):
            if(service[j] == 1):
                c11 +=1
            elif(service[j] == 2):
                c12 +=1
            else:
                c13 +=1
        
    #print(c11," ",c12," ",c13)
    p_traffic.append(c11/service.count(1))
    p_traffic.append(c12/service.count(2))
    p_traffic.append(c13/service.count(3))
    c11 = c12 = c13 = 0
    
    
#for k in range(0,len(p_traffic)):
#    print(p_traffic[k])

# %%
p_vaicle = []

for i in range(1, max(vaicle)+1):
    for j in range(0, len(service)):
        #print(j)
        if(vaicle[j] == i):
            if(service[j] == 1):
                c11 +=1
            elif(service[j] == 2):
                c12 +=1
            else:
                c13 +=1
        
    #print(c11," ",c12," ",c13)
    p_vaicle.append(c11/service.count(1))
    p_vaicle.append(c12/service.count(2))
    p_vaicle.append(c13/service.count(3))
    c11 = c12 = c13 = 0

# %%
route_in= input()
vaicle_in=input()
behave_in = input()
available_in = input()
traffic_in = input()
experience_in = input()
gender_in = input()


i = j  = 0
c=0
#print(route_in)
#print(vaicle_in)



if(int(route_in) == 1):     
    i = 0
elif(int(route_in) == 2):
    i = 3
elif(int(route_in)== 3):
    i = 6
elif(int(route_in) == 4):
    i = 9

    
#print(i)

if(int(vaicle_in) == 1 or experience_in == 1 or gender_in == 1):
    j = n = o = 0
elif(int(vaicle_in) == 2 or experience_in == 2 or gender_in == 2):
    j = n = o = 3
elif(int(vaicle_in) == 3 or experience_in == 3 ):
    j = n = 6


if(int(behave_in) == 1 or int(available_in) == 1 or traffic_in == 1):
    k = l = m =0
elif(int(behave_in) == 2 or int(available_in) == 2 or traffic_in == 2):
    k = l = m = 3  
elif(int(behave_in) == 3 or int(available_in) == 3 ):
    k = l  = 6


t_uber = p_route[i] * p_vaicle[j] * p_behave[k] * p_available[l] * p_traffic[m] * p_experience[n] * p_gender[o]
t_pathoe = p_route[i+1] * p_vaicle[j+1] * p_behave[k+1] * p_available[l+1] * p_traffic[m+1] * p_experience[n+1] * p_gender[o+1]
t_shohoz = p_route[i+2] * p_vaicle[j+2] * p_behave[k+2] * p_available[l+2] * p_traffic[m+2] * p_experience[n+2] * p_gender[o+2]


likelyhood = (t_uber * p_uber) + (t_pathoe * p_pathoe) + (t_shohoz * p_shohoz)
#print(likelyhood)
#print(t_uber," ",t_pathoe," ",t_shohoz)    

uber_class = (t_uber * p_uber)/likelyhood
pathoe_class = (t_pathoe * p_pathoe)/likelyhood
shohoz_class = (t_shohoz * p_shohoz)/likelyhood

if(uber_class >= pathoe_class and uber_class >= shohoz_class):
    print("***Uber*** is the best choise")
elif(pathoe_class >= uber_class and pathoe_class >= shohoz_class):
    print("***Pathoe*** is the best choise")
elif(shohoz_class >= pathoe_class and shohoz_class >= uber_class):
    print("***Shohoz*** is the best choise")


    
print(uber_class," ",pathoe_class," ",shohoz_class)
# Out:
# 2
# 1
# 2
# 4
# 2
# 2
# 2
# ***Pathoe*** is the best choise
# 0.24118640728730054   0.5603725356555809   0.1984410570571185

# %%
wb = open_workbook('test_data.xlsx')
sheet = wb.sheet_by_index(0)


route1 = []
vaicle1 = []
service1 = []
behave1 = []
available1 = []
traffic1 = []
experience1 = []
gender1 = []


for j in range(1,sheet.nrows):
    route1.append(int(sheet.cell_value(j,0)))

for j in range(1,sheet.nrows):
    vaicle1.append( int(sheet.cell_value(j,2)))

for j in range(1,sheet.nrows):
    service1.append( int(sheet.cell_value(j,1))) 


for j in range(1,sheet.nrows):
    behave1.append( int(sheet.cell_value(j,3))) 
    
for j in range(1,sheet.nrows):
    available1.append( int(sheet.cell_value(j,4)))
    
for j in range(1,sheet.nrows):
    traffic1.append( int(sheet.cell_value(j,5)))
    
for j in range(1,sheet.nrows):
    experience1.append( int(sheet.cell_value(j,6)))
    
for j in range(1,sheet.nrows):
    gender1.append( int(sheet.cell_value(j,7)))
    
#for j in range(0,len(gender)):
#    print(service1[j])

# %%
count0 =count1 = count2 = count3 = count4 = count5 = count6 = count7 = count8 = count9 = 0



for a in range(0,sheet.nrows-1):
    route_in= route1[a]
    vaicle_in=vaicle1[a]
    behave_in = behave1[a]
    available_in = available1[a]
    traffic_in = traffic1[a]
    experience_in = experience1[a]
    gender_in = gender1[a]


    i = j  = 0
    c=0
    #print(route_in)
    #print(vaicle_in)



    if(int(route_in) == 1):     
        i = 0
    elif(int(route_in) == 2):
        i = 3
    elif(int(route_in)== 3):
        i = 6
    elif(int(route_in) == 4):
        i = 9


    #print(i)

    if(int(vaicle_in) == 1 or experience_in == 1 or gender_in == 1):
        j = n = o = 0
    elif(int(vaicle_in) == 2 or experience_in == 2 or gender_in == 2):
        j = n = o = 3
    elif(int(vaicle_in) == 3 or experience_in == 3 ):
        j = n = 6


    if(int(behave_in) == 1 or int(available_in) == 1 or traffic_in == 1):
        k = l = m =0
    elif(int(behave_in) == 2 or int(available_in) == 2 or traffic_in == 2):
        k = l = m = 3  
    elif(int(behave_in) == 3 or int(available_in) == 3 ):
        k = l  = 6


    t_uber = p_route[i] * p_vaicle[j] * p_behave[k] * p_available[l] * p_traffic[m] * p_experience[n] * p_gender[o]
    t_pathoe = p_route[i+1] * p_vaicle[j+1] * p_behave[k+1] * p_available[l+1] * p_traffic[m+1] * p_experience[n+1] * p_gender[o+1]
    t_shohoz = p_route[i+2] * p_vaicle[j+2] * p_behave[k+2] * p_available[l+2] * p_traffic[m+2] * p_experience[n+2] * p_gender[o+2]


    likelyhood = (t_uber * p_uber) + (t_pathoe * p_pathoe) + (t_shohoz * p_shohoz)
    #print(likelyhood)
    #print(t_uber," ",t_pathoe," ",t_shohoz)    

    uber_class = (t_uber * p_uber)/likelyhood
    pathoe_class = (t_pathoe * p_pathoe)/likelyhood
    shohoz_class = (t_shohoz * p_shohoz)/likelyhood
    
    matrix = []
    c = 0
    count = 0

    if(uber_class >= pathoe_class and uber_class >= shohoz_class):
       # print("***Uber*** is the best choise")
        c=1
    elif(pathoe_class >= uber_class and pathoe_class >= shohoz_class):
        #print("***Pathoe*** is the best choise")
        c=2
    elif(shohoz_class >= pathoe_class and shohoz_class >= uber_class):
        #print("***Shohoz*** is the best choise")
        c=3
    
        
    #print(uber_class," ",pathoe_class," ",shohoz_class)
    
    if(service1[a]==1 and c==1):
        count0 +=1
        #matrix[0]= count0
        #print(a)
    elif(service1[a]==1 and c==2):
        count1 +=1
        #print(count1)
        #matrix[1] = count1
    elif(service1[a]==1 and c==3):
        count2 +=1
    elif(service1[a]==2 and c==1):
        count3 +=1
    elif(service1[a]==2 and c==2):
        count4 +=1
    elif(service1[a]==2 and c==3):
        count5 +=1
    elif(service1[a]==3 and c==1):
        count6 +=1
    elif(service1[a]==3 and c==2):
        count7 +=1
    elif(service1[a]==3 and c==3):
        count8 +=1

        
        
        
accurancy = 0
p_n = sheet.nrows
#print(p_n)
accurancy = (count0 +count4+count8)/p_n

print(accurancy)
# Out:
# 0.487012987012987
